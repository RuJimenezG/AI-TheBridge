# %%
print ("Séveret!")
# Out:
# Séveret!

# %%
print ("Lo primero de todo")
# Out:
# Lo primero de todo

# %%
print ("Cómo están los máquinas?")
# Out:
# Cómo están los máquinas?

# %% [markdown]
# Unas fotillos?
